# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
df=pd.read_csv(r"D:\PythonLIbraries\covid_worldwide.csv")

# %%
df
# Out:
#      Serial Number           Country  Total Cases Total Deaths  \
# 0                1               USA  104,196,861    1,132,935
# 1                2             India   44,682,784      530,740
# 2                3            France   39,524,311      164,233
# 3                4           Germany   37,779,833      165,711
# 4                5            Brazil   36,824,580      697,074
# ..             ...               ...          ...          ...
# 226            227  Diamond Princess          712           13
# 227            228      Vatican City           29          NaN
# 228            229    Western Sahara           10            1
# 229            230        MS Zaandam            9            2
# 230            231           Tokelau            5          NaN
#
#     Total Recovered Active Cases     Total Test     Population
# 0       101,322,779    1,741,147  1,159,832,679    334,805,269
# 1        44,150,289        1,755    915,265,788  1,406,631,776
# ...

# %%
df.head(20)
# Out:
#     Serial Number      Country  Total Cases Total Deaths Total Recovered  \
# 0               1          USA  104,196,861    1,132,935     101,322,779
# 1               2        India   44,682,784      530,740      44,150,289
# 2               3       France   39,524,311      164,233      39,264,546
# 3               4      Germany   37,779,833      165,711      37,398,100
# 4               5       Brazil   36,824,580      697,074      35,919,372
# 5               6        Japan   32,588,442       68,399      21,567,425
# 6               7     S. Korea   30,197,066       33,486      29,740,877
# 7               8        Italy   25,453,789      186,833      25,014,986
# 8               9           UK   24,274,361      204,171      24,020,088
# 9              10       Russia   21,958,696      395,108      21,356,008
# 10             11       Turkey   17,042,722      101,492             NaN
# 11             12        Spain   13,731,478      118,434      13,557,699
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 231 entries, 0 to 230
# Data columns (total 8 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Serial Number    231 non-null    int64
#  1   Country          231 non-null    object
#  2   Total Cases      231 non-null    object
#  3   Total Deaths     225 non-null    object
#  4   Total Recovered  210 non-null    object
#  5   Active Cases     212 non-null    object
#  6   Total Test       213 non-null    object
#  7   Population       228 non-null    object
# dtypes: int64(1), object(7)
# memory usage: 14.6+ KB

# %%
df1 = df.copy()

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 231 entries, 0 to 230
# Data columns (total 8 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Serial Number    231 non-null    int64
#  1   Country          231 non-null    object
#  2   Total Cases      231 non-null    object
#  3   Total Deaths     225 non-null    object
#  4   Total Recovered  210 non-null    object
#  5   Active Cases     212 non-null    object
#  6   Total Test       213 non-null    object
#  7   Population       228 non-null    object
# dtypes: int64(1), object(7)
# memory usage: 14.6+ KB

# %%
## TOTAL CASES
# removing comma by replacing it 
#to convert into numeric

# %%
df1['Total Cases']=df1['Total Cases'].str.replace(',','')

# %%
df1
# Out:
#      Serial Number           Country Total Cases Total Deaths Total Recovered  \
# 0                1               USA   104196861    1,132,935     101,322,779
# 1                2             India    44682784      530,740      44,150,289
# 2                3            France    39524311      164,233      39,264,546
# 3                4           Germany    37779833      165,711      37,398,100
# 4                5            Brazil    36824580      697,074      35,919,372
# ..             ...               ...         ...          ...             ...
# 226            227  Diamond Princess         712           13             699
# 227            228      Vatican City          29          NaN              29
# 228            229    Western Sahara          10            1               9
# 229            230        MS Zaandam           9            2               7
# 230            231           Tokelau           5          NaN             NaN
#
# ...

# %%
df1['Total Cases']=pd.to_numeric(df1['Total Cases'])

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 231 entries, 0 to 230
# Data columns (total 8 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Serial Number    231 non-null    int64
#  1   Country          231 non-null    object
#  2   Total Cases      231 non-null    int64
#  3   Total Deaths     225 non-null    object
#  4   Total Recovered  210 non-null    object
#  5   Active Cases     212 non-null    object
#  6   Total Test       213 non-null    object
#  7   Population       228 non-null    object
# dtypes: int64(2), object(6)
# memory usage: 14.6+ KB

# %%
## TOTAL DEATHS
# removing comma by replacing it 
#to convert into numeric 
#then converting null to 0
#then coverting float to int

# %%
df1['Total Deaths']=df1['Total Deaths'].str.replace(',','')

# %%
df1['Total Deaths']=pd.to_numeric(df1['Total Deaths'])
#it will change the data type to float

# %%
df1['Total Deaths']=df1['Total Deaths'].fillna(0)

# %%
df1['Total Deaths']=df1['Total Deaths'].astype(int)

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 231 entries, 0 to 230
# Data columns (total 8 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Serial Number    231 non-null    int64
#  1   Country          231 non-null    object
#  2   Total Cases      231 non-null    int64
#  3   Total Deaths     231 non-null    int32
#  4   Total Recovered  210 non-null    object
#  5   Active Cases     212 non-null    object
#  6   Total Test       213 non-null    object
#  7   Population       228 non-null    object
# dtypes: int32(1), int64(2), object(5)
# memory usage: 13.7+ KB

# %%
df1
# Out:
#      Serial Number           Country  Total Cases  Total Deaths  \
# 0                1               USA    104196861       1132935
# 1                2             India     44682784        530740
# 2                3            France     39524311        164233
# 3                4           Germany     37779833        165711
# 4                5            Brazil     36824580        697074
# ..             ...               ...          ...           ...
# 226            227  Diamond Princess          712            13
# 227            228      Vatican City           29             0
# 228            229    Western Sahara           10             1
# 229            230        MS Zaandam            9             2
# 230            231           Tokelau            5             0
#
#     Total Recovered Active Cases     Total Test     Population
# 0       101,322,779    1,741,147  1,159,832,679    334,805,269
# 1        44,150,289        1,755    915,265,788  1,406,631,776
# ...

# %%
## TOTAL RECOVERED
# removing comma by replacing it 
# convert into numeric 
#then converting null to 0
#then coverting float to int

# %%
df1['Total Recovered']=df1['Total Recovered'].str.replace(',','')

# %%
df1['Total Recovered']=pd.to_numeric(df1['Total Recovered'])

# %%
df1['Total Recovered']=df1['Total Recovered'].fillna(0)

# %%
df1['Total Recovered']=df1['Total Recovered'].astype(int)

# %%
df1
# Out:
#      Serial Number           Country  Total Cases  Total Deaths  \
# 0                1               USA    104196861       1132935
# 1                2             India     44682784        530740
# 2                3            France     39524311        164233
# 3                4           Germany     37779833        165711
# 4                5            Brazil     36824580        697074
# ..             ...               ...          ...           ...
# 226            227  Diamond Princess          712            13
# 227            228      Vatican City           29             0
# 228            229    Western Sahara           10             1
# 229            230        MS Zaandam            9             2
# 230            231           Tokelau            5             0
#
#      Total Recovered Active Cases     Total Test     Population
# 0          101322779    1,741,147  1,159,832,679    334,805,269
# 1           44150289        1,755    915,265,788  1,406,631,776
# ...

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 231 entries, 0 to 230
# Data columns (total 8 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Serial Number    231 non-null    int64
#  1   Country          231 non-null    object
#  2   Total Cases      231 non-null    int64
#  3   Total Deaths     231 non-null    int32
#  4   Total Recovered  231 non-null    int32
#  5   Active Cases     212 non-null    object
#  6   Total Test       213 non-null    object
#  7   Population       228 non-null    object
# dtypes: int32(2), int64(2), object(4)
# memory usage: 12.8+ KB

# %%
## ACTIVE CASES
# removing comma by replacing it 
# convert into numeric 
#then converting null to 0
#then coverting float to int

# %%
df1['Active Cases']=df1['Active Cases'].str.replace(',','')

# %%
df1['Active Cases']=pd.to_numeric(df1['Active Cases'])

# %%
df1['Active Cases']=df1['Active Cases'].fillna(0)

# %%
df1['Active Cases']=df1['Active Cases'].astype(int)

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 231 entries, 0 to 230
# Data columns (total 8 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Serial Number    231 non-null    int64
#  1   Country          231 non-null    object
#  2   Total Cases      231 non-null    int64
#  3   Total Deaths     231 non-null    int32
#  4   Total Recovered  231 non-null    int32
#  5   Active Cases     231 non-null    int32
#  6   Total Test       213 non-null    object
#  7   Population       228 non-null    object
# dtypes: int32(3), int64(2), object(3)
# memory usage: 11.9+ KB

# %%
# removing comma by replacing it 
# convert into numeric 
#then converting null to 0
#then coverting float to int

# %%
df1['Total Test']=df1['Total Test'].str.replace(',','')

# %%
df1['Total Test']=pd.to_numeric(df1['Total Test'])

# %%
df1['Total Test']=df1['Total Test'].fillna(0)

# %%
df1['Total Test']=df1['Total Test'].astype(int)

# %%
# removing comma by replacing it 
# convert into numeric 
#then converting null to 0
#then coverting float to int

# %%
df1['Population']=df1['Population'].str.replace(',','')

# %%
df1['Population']=pd.to_numeric(df1['Population'])

# %%
df1['Population']=df1['Population'].fillna(0)

# %%
df1['Population']=df1['Population'].astype(int)

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 231 entries, 0 to 230
# Data columns (total 8 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Serial Number    231 non-null    int64
#  1   Country          231 non-null    object
#  2   Total Cases      231 non-null    int64
#  3   Total Deaths     231 non-null    int32
#  4   Total Recovered  231 non-null    int32
#  5   Active Cases     231 non-null    int32
#  6   Total Test       231 non-null    int32
#  7   Population       231 non-null    int32
# dtypes: int32(5), int64(2), object(1)
# memory usage: 10.1+ KB

# %%
##now our dataset has no none values

# %%
df1['Recovery%']=df1['Total Recovered']/df1['Total Cases'] * 100

# %%
df1['Death%']=df1['Total Deaths']/df1['Total Cases'] * 100

# %%
df1['Active%']=df1['Active Cases']/df1['Total Cases'] * 100

# %%
df1['Test%']=df1['Total Test']/df1['Total Cases'] * 100

# %%
df1
# Out:
#      Serial Number           Country  Total Cases  Total Deaths  \
# 0                1               USA    104196861       1132935
# 1                2             India     44682784        530740
# 2                3            France     39524311        164233
# 3                4           Germany     37779833        165711
# 4                5            Brazil     36824580        697074
# ..             ...               ...          ...           ...
# 226            227  Diamond Princess          712            13
# 227            228      Vatican City           29             0
# 228            229    Western Sahara           10             1
# 229            230        MS Zaandam            9             2
# 230            231           Tokelau            5             0
#
#      Total Recovered  Active Cases  Total Test  Population   Recovery%  \
# 0          101322779       1741147  1159832679   334805269   97.241681
# ...

# %% [markdown]
# # visualisation

# %%
v2=df1.loc[:,['Country','Recovery%','Active%','Death%','Test%','Total Deaths']].head(10)
v3=df1.loc[:,['Country','Recovery%','Active%','Death%','Test%','Total Deaths']]

# %%
plt.figure(figsize=(7,7))
sns.barplot(x='Country',y='Death%',data=v2)
sns.despine
plt.show()

# %%
plt.figure(figsize=(7,7))
sns.barplot(x='Country',y='Recovery%',data=v2)
sns.despine
plt.show()

# %%
plt.figure(figsize=(7,7))
sns.barplot(x='Country',y='Active%',data=v2)
sns.despine
plt.show()
